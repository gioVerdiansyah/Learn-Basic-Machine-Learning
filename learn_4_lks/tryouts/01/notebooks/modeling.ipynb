# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("../data/heart.csv")

# %%
palette_color = ["#4B0082", "#3a2f87", "#2e4aa3", "#2170c0", "#21A9FF", "#6DC6FE", "#B3E4FF", "#E6F7FF"]

df_style = {
    "border": "1px solid black",
    "text-align": "center",
    "border-collapse": "collapse",
    "font-size": "14px",
    "background-color": palette_color[-4],
    "color": "white",
    "padding": "15px"
}

table_style = [
    {"selector": "th", "props": [("background-color", palette_color[0]), ("border", "1px solid black"), ("color", "white")]},
    {"selector": "th.col_heading", "props": [("background-color", palette_color[0]), ("border", "1px solid black"), ("color", "white"), ("padding", "10px")]},
    {"selector": "th.row_heading", "props": [("background-color", palette_color[0]), ("border", "1px solid black"), ("color", "white"), ("padding", "10px")]},
    {"selector": "tr:nth-child(even) td", "props": [("background-color", palette_color[2])]},
    {"selector": "tr:nth-child(odd) td", "props": [("background-color", palette_color[1])]},
    {"selector": "td", "props": [("border", "1px solid black")]},
]

sns.palplot(sns.color_palette(palette_color))

# %%
df.head().style.set_properties(**df_style).set_table_styles(table_style)
# Out:
# <style type="text/css">
# #T_c81c6 th {
#   background-color: #4B0082;
#   border: 1px solid black;
#   color: white;
# }
# #T_c81c6 th.col_heading {
#   background-color: #4B0082;
#   border: 1px solid black;
#   color: white;
#   padding: 10px;
# }
# #T_c81c6 th.row_heading {
#   background-color: #4B0082;
#   border: 1px solid black;
#   color: white;
#   padding: 10px;
# }
# #T_c81c6 tr:nth-child(even) td {
#   background-color: #2e4aa3;
# }
# #T_c81c6 tr:nth-child(odd) td {
#   background-color: #3a2f87;
# }
# #T_c81c6 td {
#   border: 1px solid black;
# }
# #T_c81c6_row0_col0, #T_c81c6_row0_col1, #T_c81c6_row0_col2, #T_c81c6_row0_col3, #T_c81c6_row0_col4, #T_c81c6_row0_col5, #T_c81c6_row0_col6, #T_c81c6_row0_col7, #T_c81c6_row0_col8, #T_c81c6_row0_col9, #T_c81c6_row0_col10, #T_c81c6_row0_col11, #T_c81c6_row1_col0, #T_c81c6_row1_col1, #T_c81c6_row1_col2, #T_c81c6_row1_col3, #T_c81c6_row1_col4, #T_c81c6_row1_col5, #T_c81c6_row1_col6, #T_c81c6_row1_col7, #T_c81c6_row1_col8, #T_c81c6_row1_col9, #T_c81c6_row1_col10, #T_c81c6_row1_col11, #T_c81c6_row2_col0, #T_c81c6_row2_col1, #T_c81c6_row2_col2, #T_c81c6_row2_col3, #T_c81c6_row2_col4, #T_c81c6_row2_col5, #T_c81c6_row2_col6, #T_c81c6_row2_col7, #T_c81c6_row2_col8, #T_c81c6_row2_col9, #T_c81c6_row2_col10, #T_c81c6_row2_col11, #T_c81c6_row3_col0, #T_c81c6_row3_col1, #T_c81c6_row3_col2, #T_c81c6_row3_col3, #T_c81c6_row3_col4, #T_c81c6_row3_col5, #T_c81c6_row3_col6, #T_c81c6_row3_col7, #T_c81c6_row3_col8, #T_c81c6_row3_col9, #T_c81c6_row3_col10, #T_c81c6_row3_col11, #T_c81c6_row4_col0, #T_c81c6_row4_col1, #T_c81c6_row4_col2, #T_c81c6_row4_col3, #T_c81c6_row4_col4, #T_c81c6_row4_col5, #T_c81c6_row4_col6, #T_c81c6_row4_col7, #T_c81c6_row4_col8, #T_c81c6_row4_col9, #T_c81c6_row4_col10, #T_c81c6_row4_col11 {
#   border: 1px solid black;
#   text-align: center;
#   border-collapse: collapse;
#   font-size: 14px;
#   background-color: #21A9FF;
#   color: white;
#   padding: 15px;
# }
# </style>
# <table id="T_c81c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c81c6_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_c81c6_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_c81c6_level0_col2" class="col_heading level0 col2" >ChestPainType</th>
#       <th id="T_c81c6_level0_col3" class="col_heading level0 col3" >RestingBP</th>
#       <th id="T_c81c6_level0_col4" class="col_heading level0 col4" >Cholesterol</th>
#       <th id="T_c81c6_level0_col5" class="col_heading level0 col5" >FastingBS</th>
#       <th id="T_c81c6_level0_col6" class="col_heading level0 col6" >RestingECG</th>
#       <th id="T_c81c6_level0_col7" class="col_heading level0 col7" >MaxHR</th>
#       <th id="T_c81c6_level0_col8" class="col_heading level0 col8" >ExerciseAngina</th>
#       <th id="T_c81c6_level0_col9" class="col_heading level0 col9" >Oldpeak</th>
#       <th id="T_c81c6_level0_col10" class="col_heading level0 col10" >ST_Slope</th>
#       <th id="T_c81c6_level0_col11" class="col_heading level0 col11" >HeartDisease</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c81c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c81c6_row0_col0" class="data row0 col0" >40</td>
#       <td id="T_c81c6_row0_col1" class="data row0 col1" >M</td>
#       <td id="T_c81c6_row0_col2" class="data row0 col2" >ATA</td>
#       <td id="T_c81c6_row0_col3" class="data row0 col3" >140</td>
#       <td id="T_c81c6_row0_col4" class="data row0 col4" >289</td>
#       <td id="T_c81c6_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_c81c6_row0_col6" class="data row0 col6" >Normal</td>
#       <td id="T_c81c6_row0_col7" class="data row0 col7" >172</td>
#       <td id="T_c81c6_row0_col8" class="data row0 col8" >N</td>
#       <td id="T_c81c6_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_c81c6_row0_col10" class="data row0 col10" >Up</td>
#       <td id="T_c81c6_row0_col11" class="data row0 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c81c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c81c6_row1_col0" class="data row1 col0" >49</td>
#       <td id="T_c81c6_row1_col1" class="data row1 col1" >F</td>
#       <td id="T_c81c6_row1_col2" class="data row1 col2" >NAP</td>
#       <td id="T_c81c6_row1_col3" class="data row1 col3" >160</td>
#       <td id="T_c81c6_row1_col4" class="data row1 col4" >180</td>
#       <td id="T_c81c6_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_c81c6_row1_col6" class="data row1 col6" >Normal</td>
#       <td id="T_c81c6_row1_col7" class="data row1 col7" >156</td>
#       <td id="T_c81c6_row1_col8" class="data row1 col8" >N</td>
#       <td id="T_c81c6_row1_col9" class="data row1 col9" >1.000000</td>
#       <td id="T_c81c6_row1_col10" class="data row1 col10" >Flat</td>
#       <td id="T_c81c6_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c81c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c81c6_row2_col0" class="data row2 col0" >37</td>
#       <td id="T_c81c6_row2_col1" class="data row2 col1" >M</td>
#       <td id="T_c81c6_row2_col2" class="data row2 col2" >ATA</td>
#       <td id="T_c81c6_row2_col3" class="data row2 col3" >130</td>
#       <td id="T_c81c6_row2_col4" class="data row2 col4" >283</td>
#       <td id="T_c81c6_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_c81c6_row2_col6" class="data row2 col6" >ST</td>
#       <td id="T_c81c6_row2_col7" class="data row2 col7" >98</td>
#       <td id="T_c81c6_row2_col8" class="data row2 col8" >N</td>
#       <td id="T_c81c6_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_c81c6_row2_col10" class="data row2 col10" >Up</td>
#       <td id="T_c81c6_row2_col11" class="data row2 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c81c6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c81c6_row3_col0" class="data row3 col0" >48</td>
#       <td id="T_c81c6_row3_col1" class="data row3 col1" >F</td>
#       <td id="T_c81c6_row3_col2" class="data row3 col2" >ASY</td>
#       <td id="T_c81c6_row3_col3" class="data row3 col3" >138</td>
#       <td id="T_c81c6_row3_col4" class="data row3 col4" >214</td>
#       <td id="T_c81c6_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_c81c6_row3_col6" class="data row3 col6" >Normal</td>
#       <td id="T_c81c6_row3_col7" class="data row3 col7" >108</td>
#       <td id="T_c81c6_row3_col8" class="data row3 col8" >Y</td>
#       <td id="T_c81c6_row3_col9" class="data row3 col9" >1.500000</td>
#       <td id="T_c81c6_row3_col10" class="data row3 col10" >Flat</td>
#       <td id="T_c81c6_row3_col11" class="data row3 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c81c6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c81c6_row4_col0" class="data row4 col0" >54</td>
#       <td id="T_c81c6_row4_col1" class="data row4 col1" >M</td>
#       <td id="T_c81c6_row4_col2" class="data row4 col2" >NAP</td>
#       <td id="T_c81c6_row4_col3" class="data row4 col3" >150</td>
#       <td id="T_c81c6_row4_col4" class="data row4 col4" >195</td>
#       <td id="T_c81c6_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_c81c6_row4_col6" class="data row4 col6" >Normal</td>
#       <td id="T_c81c6_row4_col7" class="data row4 col7" >122</td>
#       <td id="T_c81c6_row4_col8" class="data row4 col8" >N</td>
#       <td id="T_c81c6_row4_col9" class="data row4 col9" >0.000000</td>
#       <td id="T_c81c6_row4_col10" class="data row4 col10" >Up</td>
#       <td id="T_c81c6_row4_col11" class="data row4 col11" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
num_cols = df.select_dtypes("number").columns.to_list()
cat_cols = df.select_dtypes("object").columns.to_list()

print(f"Num cols: {num_cols}")
print(f"Cat cols: {cat_cols}")
# Out:
# Num cols: ['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak', 'HeartDisease']
# Cat cols: ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']

# %%
df.describe().T.style.set_properties(**df_style).set_table_styles(table_style)
# Out:
# <style type="text/css">
# #T_9b4c5 th {
#   background-color: #4B0082;
#   border: 1px solid black;
#   color: white;
# }
# #T_9b4c5 th.col_heading {
#   background-color: #4B0082;
#   border: 1px solid black;
#   color: white;
#   padding: 10px;
# }
# #T_9b4c5 th.row_heading {
#   background-color: #4B0082;
#   border: 1px solid black;
#   color: white;
#   padding: 10px;
# }
# #T_9b4c5 tr:nth-child(even) td {
#   background-color: #2e4aa3;
# }
# #T_9b4c5 tr:nth-child(odd) td {
#   background-color: #3a2f87;
# }
# #T_9b4c5 td {
#   border: 1px solid black;
# }
# #T_9b4c5_row0_col0, #T_9b4c5_row0_col1, #T_9b4c5_row0_col2, #T_9b4c5_row0_col3, #T_9b4c5_row0_col4, #T_9b4c5_row0_col5, #T_9b4c5_row0_col6, #T_9b4c5_row0_col7, #T_9b4c5_row1_col0, #T_9b4c5_row1_col1, #T_9b4c5_row1_col2, #T_9b4c5_row1_col3, #T_9b4c5_row1_col4, #T_9b4c5_row1_col5, #T_9b4c5_row1_col6, #T_9b4c5_row1_col7, #T_9b4c5_row2_col0, #T_9b4c5_row2_col1, #T_9b4c5_row2_col2, #T_9b4c5_row2_col3, #T_9b4c5_row2_col4, #T_9b4c5_row2_col5, #T_9b4c5_row2_col6, #T_9b4c5_row2_col7, #T_9b4c5_row3_col0, #T_9b4c5_row3_col1, #T_9b4c5_row3_col2, #T_9b4c5_row3_col3, #T_9b4c5_row3_col4, #T_9b4c5_row3_col5, #T_9b4c5_row3_col6, #T_9b4c5_row3_col7, #T_9b4c5_row4_col0, #T_9b4c5_row4_col1, #T_9b4c5_row4_col2, #T_9b4c5_row4_col3, #T_9b4c5_row4_col4, #T_9b4c5_row4_col5, #T_9b4c5_row4_col6, #T_9b4c5_row4_col7, #T_9b4c5_row5_col0, #T_9b4c5_row5_col1, #T_9b4c5_row5_col2, #T_9b4c5_row5_col3, #T_9b4c5_row5_col4, #T_9b4c5_row5_col5, #T_9b4c5_row5_col6, #T_9b4c5_row5_col7, #T_9b4c5_row6_col0, #T_9b4c5_row6_col1, #T_9b4c5_row6_col2, #T_9b4c5_row6_col3, #T_9b4c5_row6_col4, #T_9b4c5_row6_col5, #T_9b4c5_row6_col6, #T_9b4c5_row6_col7 {
#   border: 1px solid black;
#   text-align: center;
#   border-collapse: collapse;
#   font-size: 14px;
#   background-color: #21A9FF;
#   color: white;
#   padding: 15px;
# }
# </style>
# <table id="T_9b4c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b4c5_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_9b4c5_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_9b4c5_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_9b4c5_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_9b4c5_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_9b4c5_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_9b4c5_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_9b4c5_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b4c5_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_9b4c5_row0_col0" class="data row0 col0" >918.000000</td>
#       <td id="T_9b4c5_row0_col1" class="data row0 col1" >53.510893</td>
#       <td id="T_9b4c5_row0_col2" class="data row0 col2" >9.432617</td>
#       <td id="T_9b4c5_row0_col3" class="data row0 col3" >28.000000</td>
#       <td id="T_9b4c5_row0_col4" class="data row0 col4" >47.000000</td>
#       <td id="T_9b4c5_row0_col5" class="data row0 col5" >54.000000</td>
#       <td id="T_9b4c5_row0_col6" class="data row0 col6" >60.000000</td>
#       <td id="T_9b4c5_row0_col7" class="data row0 col7" >77.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9b4c5_level0_row1" class="row_heading level0 row1" >RestingBP</th>
#       <td id="T_9b4c5_row1_col0" class="data row1 col0" >918.000000</td>
#       <td id="T_9b4c5_row1_col1" class="data row1 col1" >132.396514</td>
#       <td id="T_9b4c5_row1_col2" class="data row1 col2" >18.514154</td>
#       <td id="T_9b4c5_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_9b4c5_row1_col4" class="data row1 col4" >120.000000</td>
#       <td id="T_9b4c5_row1_col5" class="data row1 col5" >130.000000</td>
#       <td id="T_9b4c5_row1_col6" class="data row1 col6" >140.000000</td>
#       <td id="T_9b4c5_row1_col7" class="data row1 col7" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9b4c5_level0_row2" class="row_heading level0 row2" >Cholesterol</th>
#       <td id="T_9b4c5_row2_col0" class="data row2 col0" >918.000000</td>
#       <td id="T_9b4c5_row2_col1" class="data row2 col1" >198.799564</td>
#       <td id="T_9b4c5_row2_col2" class="data row2 col2" >109.384145</td>
#       <td id="T_9b4c5_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_9b4c5_row2_col4" class="data row2 col4" >173.250000</td>
#       <td id="T_9b4c5_row2_col5" class="data row2 col5" >223.000000</td>
#       <td id="T_9b4c5_row2_col6" class="data row2 col6" >267.000000</td>
#       <td id="T_9b4c5_row2_col7" class="data row2 col7" >603.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9b4c5_level0_row3" class="row_heading level0 row3" >FastingBS</th>
#       <td id="T_9b4c5_row3_col0" class="data row3 col0" >918.000000</td>
#       <td id="T_9b4c5_row3_col1" class="data row3 col1" >0.233115</td>
#       <td id="T_9b4c5_row3_col2" class="data row3 col2" >0.423046</td>
#       <td id="T_9b4c5_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_9b4c5_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_9b4c5_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_9b4c5_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_9b4c5_row3_col7" class="data row3 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9b4c5_level0_row4" class="row_heading level0 row4" >MaxHR</th>
#       <td id="T_9b4c5_row4_col0" class="data row4 col0" >918.000000</td>
#       <td id="T_9b4c5_row4_col1" class="data row4 col1" >136.809368</td>
#       <td id="T_9b4c5_row4_col2" class="data row4 col2" >25.460334</td>
#       <td id="T_9b4c5_row4_col3" class="data row4 col3" >60.000000</td>
#       <td id="T_9b4c5_row4_col4" class="data row4 col4" >120.000000</td>
#       <td id="T_9b4c5_row4_col5" class="data row4 col5" >138.000000</td>
#       <td id="T_9b4c5_row4_col6" class="data row4 col6" >156.000000</td>
#       <td id="T_9b4c5_row4_col7" class="data row4 col7" >202.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9b4c5_level0_row5" class="row_heading level0 row5" >Oldpeak</th>
#       <td id="T_9b4c5_row5_col0" class="data row5 col0" >918.000000</td>
#       <td id="T_9b4c5_row5_col1" class="data row5 col1" >0.887364</td>
#       <td id="T_9b4c5_row5_col2" class="data row5 col2" >1.066570</td>
#       <td id="T_9b4c5_row5_col3" class="data row5 col3" >-2.600000</td>
#       <td id="T_9b4c5_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_9b4c5_row5_col5" class="data row5 col5" >0.600000</td>
#       <td id="T_9b4c5_row5_col6" class="data row5 col6" >1.500000</td>
#       <td id="T_9b4c5_row5_col7" class="data row5 col7" >6.200000</td>
#     </tr>
#     <tr>
#       <th id="T_9b4c5_level0_row6" class="row_heading level0 row6" >HeartDisease</th>
#       <td id="T_9b4c5_row6_col0" class="data row6 col0" >918.000000</td>
#       <td id="T_9b4c5_row6_col1" class="data row6 col1" >0.553377</td>
#       <td id="T_9b4c5_row6_col2" class="data row6 col2" >0.497414</td>
#       <td id="T_9b4c5_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_9b4c5_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_9b4c5_row6_col5" class="data row6 col5" >1.000000</td>
#       <td id="T_9b4c5_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_9b4c5_row6_col7" class="data row6 col7" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.describe(include="object").T.style.set_properties(**df_style).set_table_styles(table_style)
# Out:
# <style type="text/css">
# #T_a635d th {
#   background-color: #4B0082;
#   border: 1px solid black;
#   color: white;
# }
# #T_a635d th.col_heading {
#   background-color: #4B0082;
#   border: 1px solid black;
#   color: white;
#   padding: 10px;
# }
# #T_a635d th.row_heading {
#   background-color: #4B0082;
#   border: 1px solid black;
#   color: white;
#   padding: 10px;
# }
# #T_a635d tr:nth-child(even) td {
#   background-color: #2e4aa3;
# }
# #T_a635d tr:nth-child(odd) td {
#   background-color: #3a2f87;
# }
# #T_a635d td {
#   border: 1px solid black;
# }
# #T_a635d_row0_col0, #T_a635d_row0_col1, #T_a635d_row0_col2, #T_a635d_row0_col3, #T_a635d_row1_col0, #T_a635d_row1_col1, #T_a635d_row1_col2, #T_a635d_row1_col3, #T_a635d_row2_col0, #T_a635d_row2_col1, #T_a635d_row2_col2, #T_a635d_row2_col3, #T_a635d_row3_col0, #T_a635d_row3_col1, #T_a635d_row3_col2, #T_a635d_row3_col3, #T_a635d_row4_col0, #T_a635d_row4_col1, #T_a635d_row4_col2, #T_a635d_row4_col3 {
#   border: 1px solid black;
#   text-align: center;
#   border-collapse: collapse;
#   font-size: 14px;
#   background-color: #21A9FF;
#   color: white;
#   padding: 15px;
# }
# </style>
# <table id="T_a635d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a635d_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a635d_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_a635d_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_a635d_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a635d_level0_row0" class="row_heading level0 row0" >Sex</th>
#       <td id="T_a635d_row0_col0" class="data row0 col0" >918</td>
#       <td id="T_a635d_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_a635d_row0_col2" class="data row0 col2" >M</td>
#       <td id="T_a635d_row0_col3" class="data row0 col3" >725</td>
#     </tr>
#     <tr>
#       <th id="T_a635d_level0_row1" class="row_heading level0 row1" >ChestPainType</th>
#       <td id="T_a635d_row1_col0" class="data row1 col0" >918</td>
#       <td id="T_a635d_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_a635d_row1_col2" class="data row1 col2" >ASY</td>
#       <td id="T_a635d_row1_col3" class="data row1 col3" >496</td>
#     </tr>
#     <tr>
#       <th id="T_a635d_level0_row2" class="row_heading level0 row2" >RestingECG</th>
#       <td id="T_a635d_row2_col0" class="data row2 col0" >918</td>
#       <td id="T_a635d_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_a635d_row2_col2" class="data row2 col2" >Normal</td>
#       <td id="T_a635d_row2_col3" class="data row2 col3" >552</td>
#     </tr>
#     <tr>
#       <th id="T_a635d_level0_row3" class="row_heading level0 row3" >ExerciseAngina</th>
#       <td id="T_a635d_row3_col0" class="data row3 col0" >918</td>
#       <td id="T_a635d_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_a635d_row3_col2" class="data row3 col2" >N</td>
#       <td id="T_a635d_row3_col3" class="data row3 col3" >547</td>
#     </tr>
#     <tr>
#       <th id="T_a635d_level0_row4" class="row_heading level0 row4" >ST_Slope</th>
#       <td id="T_a635d_row4_col0" class="data row4 col0" >918</td>
#       <td id="T_a635d_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_a635d_row4_col2" class="data row4 col2" >Flat</td>
#       <td id="T_a635d_row4_col3" class="data row4 col3" >460</td>
#     </tr>
#   </tbody>
# </table>

# %%
import math

n_cols = 3
n_rows = math.ceil(len(num_cols) / n_cols)
fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*5, n_rows*5))
ax = ax.flatten()

for i, col in enumerate(num_cols):
  data = df[col]

  ax[i].set_title(col)
  sns.boxplot(
      y=data,
      ax=ax[i]
  )
  ax[i].set_ylabel(None)

for j in range(len(num_cols), n_rows * n_cols):
  fig.delaxes(ax[j])

plt.show()

# %%
out_cols = ["RestingBP", "Cholesterol", "Oldpeak"]

df_clear_out = df.copy()

for col in out_cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q3 - 1.50 * iqr
  upper_bound = q3 + 1.50 * iqr
  
  df_clear_out = df_clear_out[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

df_clear_out.shape
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16972\4196922828.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_clear_out = df_clear_out[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
# C:\Users\User\AppData\Local\Temp\ipykernel_16972\4196922828.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_clear_out = df_clear_out[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
# (660, 12)

# %%
n_cols = 3
n_rows = math.ceil(len(out_cols) / n_cols)
fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*5, n_rows*5))
ax = ax.flatten()

for i, col in enumerate(out_cols):
  data = df_clear_out[col]

  ax[i].set_title(col)
  sns.boxplot(
      y=data,
      ax=ax[i]
  )
  ax[i].set_ylabel(None)

for j in range(len(out_cols), n_rows * n_cols):
  fig.delaxes(ax[j])

plt.show()

# %%
f_pie_cols = cat_cols + ["HeartDisease"]

n_cols = 3
n_rows = math.ceil(len(f_pie_cols) / n_cols)

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_rows*8, n_cols*4))
ax = ax.flatten()

for i, col in enumerate(f_pie_cols):
  data = df_clear_out[col].value_counts()
  
  ax[i].set_title(col)
  wedges, texts, autotexts = ax[i].pie(
    x=data,
    labels=data.keys(),
    autopct="%.2f%%",
    startangle=90,
    shadow=True,
    explode=[0.08 for _ in range(len(data.keys()))]
  )
  
for j in range(len(f_pie_cols), n_rows * n_cols):
  fig.delaxes(ax[j])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sampling

# %%
def oversampling(X, y):
  df = pd.DataFrame(X)
  name = y.to_frame().columns[0]
  df[name] = y
  
  classes = df[name].unique()
  max_count = df[name].value_counts().max()
  # min_count = df[name].value_counts().min() # under sampler
  
  df_balanced = pd.concat([
    df[df[name] == c].sample(max_count, replace=True, random_state=42)
    for c in classes
  ])
  
  return df_balanced

# %%
df_balanced = oversampling(df_clear_out.drop(columns=["Sex"]), df.Sex)
df_balanced.head()
# Out:
#      Age ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 162   47           ATA        160          263          0     Normal    174
# 808   35           ASY        126          282          0        LVH    156
# 653   42           NAP        130          180          0     Normal    150
# 556   75           ASY        160          310          1     Normal    112
# 168   58           ASY        135          222          0     Normal    100
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease Sex
# 162              N      0.0       Up             0   M
# 808              Y      0.0       Up             1   M
# 653              N      0.0       Up             0   M
# 556              Y      2.0     Down             0   M
# 168              N      0.0       Up             0   M

# %%
print(df_balanced.shape)

f_pie_cols = df_balanced.select_dtypes("object").columns.to_list() + ["HeartDisease"]

n_cols = 3
n_rows = int(np.ceil(len(f_pie_cols) / n_cols))

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_rows*8, n_cols*4))
ax = ax.flatten()

for i, col in enumerate(f_pie_cols):
  data = df_balanced[col].value_counts()
  
  ax[i].set_title(col)
  wedges, texts, autotexts = ax[i].pie(
    x=data,
    labels=data.keys(),
    autopct="%.2f%%",
    startangle=90,
    shadow=True,
    explode=[0.08 for _ in range(len(data.keys()))]
  )
  
for j in range(len(f_pie_cols), n_rows * n_cols):
  fig.delaxes(ax[j])
    
plt.tight_layout()
plt.show()
# Out:
# (1014, 12)

# %% [markdown]
# ### Split

# %%
def train_test_split(X, y, test_size=0.2, random_state=None):
  if random_state:
    np.random.seed(random_state)
  
  n_sample = len(X)
  
  shuffle_indices = np.random.permutation(np.arange(n_sample))
  
  test_size = round(test_size * n_sample)
  train_size = n_sample - test_size
  
  train_indices = shuffle_indices[:train_size]
  test_indices = shuffle_indices[test_size:]
  
  X_train, X_test = X.iloc[train_indices], X.iloc[test_indices]
  y_train, y_test = y.iloc[train_indices], y.iloc[test_indices]
  
  return [X_train, X_test, y_train, y_test]

# Apply feature selection
X = df_balanced.drop(columns=["HeartDisease"])
y = df_balanced["HeartDisease"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ### Encoding

# %%
def label_decode(df: pd.DataFrame):
  unq_map = dict()
  for col in cat_cols:
    unq = df[col].unique()
    unq_map[col] = {v: k for k, v in enumerate(unq)}
    df[col] = df[col].map(unq_map[col])
    
  return df, unq_map

df_encoded, struct = label_decode(df)

df_encoded.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    0              0        140          289          0           0
# 1   49    1              1        160          180          0           0
# 2   37    0              0        130          283          0           1
# 3   48    1              2        138          214          0           0
# 4   54    0              1        150          195          0           0
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         0             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         0             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         0             0

# %%
struct
# Out:
# {'Sex': {'M': 0, 'F': 1},
#  'ChestPainType': {'ATA': 0, 'NAP': 1, 'ASY': 2, 'TA': 3},
#  'RestingECG': {'Normal': 0, 'ST': 1, 'LVH': 2},
#  'ExerciseAngina': {'N': 0, 'Y': 1},
#  'ST_Slope': {'Up': 0, 'Flat': 1, 'Down': 2}}

# %% [markdown]
# ### Sclaer

# %%
def min_max_scaler(X: pd.DataFrame):
  return ((X - X.min(axis=0)) / (X.max(axis=0) - X.mean(axis=0)))

def z_score(X: pd.DataFrame):
  return ((X - X.mean(axis=0)) / X.std(axis=0))

# %%
df_mm_scaler = min_max_scaler(df_encoded)
df_mm_scaler.head()
# Out:
#         Age       Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0  0.510875  0.000000       0.000000   2.070899     0.714992        0.0
# 1  0.894031  1.266207       0.646024   2.366742     0.445324        0.0
# 2  0.383156  0.000000       0.000000   1.922978     0.700148        0.0
# 3  0.851459  1.266207       1.292048   2.041315     0.529440        0.0
# 4  1.106896  0.000000       0.646024   2.218820     0.482434        0.0
#
#    RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# 0    0.000000  1.718038        0.000000  0.489399    0.0000      0.000000
# 1    0.000000  1.472604        0.000000  0.677630    0.7344      2.239024
# 2    0.716069  0.582906        0.000000  0.489399    0.0000      0.000000
# 3    0.000000  0.736302        1.678245  0.771745    0.7344      2.239024
# 4    0.000000  0.951057        0.000000  0.489399    0.0000      0.000000

# %%
df_std_scaler = min_max_scaler(df_encoded)
df_std_scaler.head()
# Out:
#         Age       Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0  0.510875  0.000000       0.000000   2.070899     0.714992        0.0
# 1  0.894031  1.266207       0.646024   2.366742     0.445324        0.0
# 2  0.383156  0.000000       0.000000   1.922978     0.700148        0.0
# 3  0.851459  1.266207       1.292048   2.041315     0.529440        0.0
# 4  1.106896  0.000000       0.646024   2.218820     0.482434        0.0
#
#    RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# 0    0.000000  1.718038        0.000000  0.489399    0.0000      0.000000
# 1    0.000000  1.472604        0.000000  0.677630    0.7344      2.239024
# 2    0.716069  0.582906        0.000000  0.489399    0.0000      0.000000
# 3    0.000000  0.736302        1.678245  0.771745    0.7344      2.239024
# 4    0.000000  0.951057        0.000000  0.489399    0.0000      0.000000

# %%
df_no_scaler = df_encoded.copy()
df_no_scaler.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    0              0        140          289          0           0
# 1   49    1              1        160          180          0           0
# 2   37    0              0        130          283          0           1
# 3   48    1              2        138          214          0           0
# 4   54    0              1        150          195          0           0
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         0             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         0             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         0             0

# %% [markdown]
# ### Build Model

# %%
class KNN:
  def __init__(self, k:int):
    self.k = k
  
  def minkowski_distance(X, y, p):
    return np.power(np.sum(np.abs(X - y) ** p), 1/p)
  
  def fit(self, X, y):
    self.X_train = X
    self.y_train = y
  
  def predict(self, X):
    preds = [self._predict_process(x) for x in X]
    return np.array(preds)
  
  def _predict_process(self, X):
    # Komputai jarak antara x dan semua training set
    distances = [self.minkowski_distance(X, x_train) for x_train in self.X_train]
    # Urutkan berdasarkan jarak dan jadikan indexs dari k neighbors pertama
    k_indices = np.argsort(distances)[:self.k]
    # Esktrak label training sampel dari knn
    k_nearest_labels = [self.y_train[i] for i in k_indices]
    # mendapatkan class label paling terdekat
    return np.bincount(k_nearest_labels).argmax()
