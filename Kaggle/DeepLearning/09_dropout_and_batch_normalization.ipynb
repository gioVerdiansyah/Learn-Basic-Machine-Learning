# %% [markdown]
# **Introduction**<br>
# There's more to the world of deep learning than just dense layers. There are dozens of kinds of layers you might add to a model. (Try browsing through the [Keras docs](https://www.tensorflow.org/api_docs/python/tf/keras/layers/) for a sample!) Some are like dense layers and define connections between neurons, and others can do preprocessing or transformations of other sorts.
#
# In this lesson, we'll learn about a two kinds of special layers, not containing any neurons themselves, but that add some functionality that can sometimes benefit a model in various ways. Both are commonly used in modern architectures.
#
# **Dropout**<br>
# The first of these is the "dropout layer", which can help correct overfitting.
#
# In the last lesson we talked about how overfitting is caused by the network learning spurious patterns in the training data. To recognize these spurious patterns a network will often rely on very a specific combinations of weight, a kind of "conspiracy" of weights. Being so specific, they tend to be fragile: remove one and the conspiracy falls apart.
#
# This is the idea behind dropout. To break up these conspiracies, we randomly drop out some fraction of a layer's input units every step of training, making it much harder for the network to learn those spurious patterns in the training data. Instead, it has to search for broad, general patterns, whose weight patterns tend to be more robust.
#
# <center><img src="https://storage.googleapis.com/kaggle-media/learn/images/a86utxY.gif" width="600" alt="An animation of a network cycling through various random dropout configurations."></center>
# <center>Here, 50% dropout has been added between the two hidden layers.</center>
#
# <br>
#
# **Adding Dropout**<br>
# In Keras, the dropout rate argument rate defines what percentage of the input units to shut off. Put the Dropout layer just before the layer you want the dropout applied to:
# <pre><code>keras.Sequential([
#     # ...
#     layers.Dropout(rate=0.3), # apply 30% dropout to the next layer
#     layers.Dense(16),
#     # ...
# ])</code></pre>
#
# <br>
#
# **Batch Normalization**<br>
# The next special layer we'll look at performs "batch normalization" (or "batchnorm"), which can help correct training that is slow or unstable.
#
# With neural networks, it's generally a good idea to put all of your data on a common scale, perhaps with something like scikit-learn's [StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html) or [MinMaxScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html). The reason is that SGD will shift the network weights in proportion to how large an activation the data produces. Features that tend to produce activations of very different sizes can make for unstable training behavior.
#
# Now, if it's good to normalize the data before it goes into the network, maybe also normalizing inside the network would be better! In fact, we have a special kind of layer that can do this, the batch normalization layer. A batch normalization layer looks at each batch as it comes in, first normalizing the batch with its own mean and standard deviation, and then also putting the data on a new scale with two trainable rescaling parameters. Batchnorm, in effect, performs a kind of coordinated rescaling of its inputs.
#
# Most often, batchnorm is added as an aid to the optimization process (though it can sometimes also help prediction performance). Models with batchnorm tend to need fewer epochs to complete training. Moreover, batchnorm can also fix various problems that can cause the training to get "stuck". Consider adding batch normalization to your models, especially if you're having trouble during training.
#
# <br>
#
# **Adding Batch Normalization**<br>
# It seems that batch normalization can be used at almost any point in a network. You can put it after a layer...
#
# <pre><code>layers.Dense(16, activation='relu'),
# layers.BatchNormalization(),</code></pre>
#
# ... or between a layer and its activation function:
#
# <pre><code>layers.Dense(16),
# layers.BatchNormalization(),
# layers.Activation('relu'),</code></pre>
#
# And if you add it as the first layer of your network it can act as a kind of adaptive preprocessor, standing in for something like Sci-Kit Learn's StandardScaler.
#
#
# <br>
#
# **Example - Using Dropout and Batch Normalization**<br>
# Let's continue developing the *Red Wine* model. Now we'll increase the capacity even more, but add dropout to control overfitting and batch normalization to speed up optimization. This time, we'll also leave off standardizing the data, to demonstrate how batch normalization can stabalize the training.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)

# Create validation and training split
df = pd.read_csv("./resources/datasets/red-wine.csv")
df_train = df.sample(frac=0.7, random_state=0)
df_valid = df.drop(df_train.index)


# Split features and target
X_train = df_train.drop(columns=['quality'])
X_valid = df_valid.drop(columns=['quality'])
y_train = df_train['quality']
y_valid = df_valid['quality']

# %% [markdown]
# When adding dropout, you may need to increase the number of units in your Dense layers.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(1024, activation='relu', input_shape=[11]),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1024, activation='relu', input_shape=[11]),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1024, activation='relu', input_shape=[11]),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1)
])
# Out:
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# There's nothing to change this time in how we set up the training.

# %%
model.compile(
    optimizer='adam',
    loss='mae'
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=200,
)


# Show History
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
# Out:
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/200
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 5/5 [==============================] - 4s 181ms/step - loss: 5.5532 - val_loss: 9.9055
# Epoch 2/200
# 5/5 [==============================] - 0s 83ms/step - loss: 5.3474 - val_loss: 3.6373
# Epoch 3/200
# 5/5 [==============================] - 0s 89ms/step - loss: 5.1449 - val_loss: 6.1592
# Epoch 4/200
# 5/5 [==============================] - 0s 85ms/step - loss: 4.8954 - val_loss: 3.3802
# Epoch 5/200
# 5/5 [==============================] - 0s 86ms/step - loss: 4.6334 - val_loss: 11.5242
# Epoch 6/200
# 5/5 [==============================] - 0s 93ms/step - loss: 4.3250 - val_loss: 4.6679
# Epoch 7/200
# 5/5 [==============================] - 0s 82ms/step - loss: 3.9774 - val_loss: 6.6468
# Epoch 8/200
# 5/5 [==============================] - 0s 96ms/step - loss: 3.5762 - val_loss: 3.6522
# Epoch 9/200
# 5/5 [==============================] - 0s 93ms/step - loss: 3.1786 - val_loss: 2.6857
# Epoch 10/200
# 5/5 [==============================] - 1s 131ms/step - loss: 2.7435 - val_loss: 1.6980
# Epoch 11/200
# 5/5 [==============================] - 0s 89ms/step - loss: 2.3333 - val_loss: 3.3581
# Epoch 12/200
# 5/5 [==============================] - 1s 127ms/step - loss: 1.9396 - val_loss: 1.7489
# Epoch 13/200
# 5/5 [==============================] - 0s 99ms/step - loss: 1.6889 - val_loss: 3.6036
# Epoch 14/200
# 5/5 [==============================] - 1s 164ms/step - loss: 1.5568 - val_loss: 1.3044
# Epoch 15/200
# 5/5 [==============================] - 1s 115ms/step - loss: 1.4029 - val_loss: 1.0320
# Epoch 16/200
# 5/5 [==============================] - 0s 90ms/step - loss: 1.4005 - val_loss: 1.9748
# Epoch 17/200
# 5/5 [==============================] - 0s 88ms/step - loss: 1.3366 - val_loss: 1.3367
# Epoch 18/200
# 5/5 [==============================] - 0s 87ms/step - loss: 1.2528 - val_loss: 2.9280
# Epoch 19/200
# 5/5 [==============================] - 1s 130ms/step - loss: 1.2807 - val_loss: 2.1874
# Epoch 20/200
# 5/5 [==============================] - 1s 170ms/step - loss: 1.2048 - val_loss: 2.6979
# Epoch 21/200
# 5/5 [==============================] - 1s 164ms/step - loss: 1.1803 - val_loss: 1.5714
# Epoch 22/200
# 5/5 [==============================] - 0s 94ms/step - loss: 1.1209 - val_loss: 2.1238
# Epoch 23/200
# 5/5 [==============================] - 0s 95ms/step - loss: 1.1110 - val_loss: 1.2928
# Epoch 24/200
# 5/5 [==============================] - 0s 100ms/step - loss: 1.1183 - val_loss: 1.4571
# Epoch 25/200
# 5/5 [==============================] - 0s 97ms/step - loss: 1.0894 - val_loss: 1.4450
# Epoch 26/200
# 5/5 [==============================] - 0s 94ms/step - loss: 1.0828 - val_loss: 0.7598
# Epoch 27/200
# 5/5 [==============================] - 1s 104ms/step - loss: 1.0891 - val_loss: 1.0475
# Epoch 28/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.9787 - val_loss: 0.7043
# Epoch 29/200
# 5/5 [==============================] - 0s 100ms/step - loss: 0.9755 - val_loss: 0.8690
# Epoch 30/200
# 5/5 [==============================] - 1s 125ms/step - loss: 1.0414 - val_loss: 0.6845
# Epoch 31/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.9632 - val_loss: 0.6477
# Epoch 32/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.9734 - val_loss: 0.7945
# Epoch 33/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.9767 - val_loss: 0.8091
# Epoch 34/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.9696 - val_loss: 0.6874
# Epoch 35/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.9560 - val_loss: 0.6527
# Epoch 36/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.9503 - val_loss: 0.7568
# Epoch 37/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.9626 - val_loss: 0.5906
# Epoch 38/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.9593 - val_loss: 0.6704
# Epoch 39/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.9240 - val_loss: 0.6093
# Epoch 40/200
# 5/5 [==============================] - 0s 101ms/step - loss: 0.8870 - val_loss: 0.6317
# Epoch 41/200
# 5/5 [==============================] - 1s 105ms/step - loss: 0.8734 - val_loss: 0.6580
# Epoch 42/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.8502 - val_loss: 0.6681
# Epoch 43/200
# 5/5 [==============================] - 0s 100ms/step - loss: 0.9328 - val_loss: 0.5917
# Epoch 44/200
# 5/5 [==============================] - 0s 102ms/step - loss: 0.9411 - val_loss: 0.6630
# Epoch 45/200
# 5/5 [==============================] - 0s 101ms/step - loss: 0.9089 - val_loss: 0.6336
# Epoch 46/200
# 5/5 [==============================] - 0s 100ms/step - loss: 0.8970 - val_loss: 0.5795
# Epoch 47/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.8499 - val_loss: 0.6312
# Epoch 48/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.8325 - val_loss: 0.5724
# Epoch 49/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.8251 - val_loss: 0.6381
# Epoch 50/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.8517 - val_loss: 0.6724
# Epoch 51/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.8369 - val_loss: 0.6605
# Epoch 52/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.8155 - val_loss: 0.5964
# Epoch 53/200
# 5/5 [==============================] - 0s 100ms/step - loss: 0.7997 - val_loss: 0.6073
# Epoch 54/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.8391 - val_loss: 0.6081
# Epoch 55/200
# 5/5 [==============================] - 0s 102ms/step - loss: 0.7937 - val_loss: 0.6573
# Epoch 56/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.8107 - val_loss: 0.5807
# Epoch 57/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.8020 - val_loss: 0.7201
# Epoch 58/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.7571 - val_loss: 0.6065
# Epoch 59/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.8558 - val_loss: 0.6774
# Epoch 60/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.8192 - val_loss: 0.6065
# Epoch 61/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.7751 - val_loss: 0.5894
# Epoch 62/200
# 5/5 [==============================] - 1s 106ms/step - loss: 0.7804 - val_loss: 0.5923
# Epoch 63/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.7886 - val_loss: 0.6515
# Epoch 64/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.7593 - val_loss: 0.5888
# Epoch 65/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.8036 - val_loss: 0.5711
# Epoch 66/200
# 5/5 [==============================] - 0s 94ms/step - loss: 0.7531 - val_loss: 0.6500
# Epoch 67/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.7221 - val_loss: 0.5656
# Epoch 68/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.8144 - val_loss: 0.5891
# Epoch 69/200
# 5/5 [==============================] - 1s 106ms/step - loss: 0.8319 - val_loss: 0.6171
# Epoch 70/200
# 5/5 [==============================] - 0s 102ms/step - loss: 0.7804 - val_loss: 0.6318
# Epoch 71/200
# 5/5 [==============================] - 0s 100ms/step - loss: 0.7837 - val_loss: 0.5626
# Epoch 72/200
# 5/5 [==============================] - 1s 191ms/step - loss: 0.7710 - val_loss: 0.6204
# Epoch 73/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.7514 - val_loss: 0.6189
# Epoch 74/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.8189 - val_loss: 0.7377
# Epoch 75/200
# 5/5 [==============================] - 1s 107ms/step - loss: 0.7551 - val_loss: 0.5661
# Epoch 76/200
# 5/5 [==============================] - 1s 108ms/step - loss: 0.7625 - val_loss: 0.5692
# Epoch 77/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.7259 - val_loss: 0.6374
# Epoch 78/200
# 5/5 [==============================] - 0s 90ms/step - loss: 0.7550 - val_loss: 0.6095
# Epoch 79/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.7410 - val_loss: 0.5698
# Epoch 80/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.8021 - val_loss: 0.6131
# Epoch 81/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.7237 - val_loss: 0.5688
# Epoch 82/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.7705 - val_loss: 0.6639
# Epoch 83/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.7572 - val_loss: 0.7051
# Epoch 84/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.7361 - val_loss: 0.6099
# Epoch 85/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.7532 - val_loss: 0.7253
# Epoch 86/200
# 5/5 [==============================] - 1s 157ms/step - loss: 0.7942 - val_loss: 0.6643
# Epoch 87/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.7305 - val_loss: 0.6556
# Epoch 88/200
# 5/5 [==============================] - 1s 152ms/step - loss: 0.7675 - val_loss: 0.6270
# Epoch 89/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.7753 - val_loss: 0.5877
# Epoch 90/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.7424 - val_loss: 0.5807
# Epoch 91/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.7188 - val_loss: 0.6041
# Epoch 92/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.7063 - val_loss: 0.5275
# Epoch 93/200
# 5/5 [==============================] - 1s 105ms/step - loss: 0.6895 - val_loss: 0.5773
# Epoch 94/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.7406 - val_loss: 0.5862
# Epoch 95/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.7229 - val_loss: 0.5507
# Epoch 96/200
# 5/5 [==============================] - 1s 147ms/step - loss: 0.6732 - val_loss: 0.5613
# Epoch 97/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.7186 - val_loss: 0.5968
# Epoch 98/200
# 5/5 [==============================] - 1s 109ms/step - loss: 0.7130 - val_loss: 0.5695
# Epoch 99/200
# 5/5 [==============================] - 1s 167ms/step - loss: 0.6954 - val_loss: 0.5773
# Epoch 100/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.6942 - val_loss: 0.5642
# Epoch 101/200
# 5/5 [==============================] - 0s 101ms/step - loss: 0.6620 - val_loss: 0.5365
# Epoch 102/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.7392 - val_loss: 0.5857
# Epoch 103/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.7201 - val_loss: 0.6125
# Epoch 104/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.7224 - val_loss: 0.5501
# Epoch 105/200
# 5/5 [==============================] - 1s 113ms/step - loss: 0.6916 - val_loss: 0.5462
# Epoch 106/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.7161 - val_loss: 0.5814
# Epoch 107/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.6847 - val_loss: 0.5986
# Epoch 108/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.7147 - val_loss: 0.5924
# Epoch 109/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.6984 - val_loss: 0.6393
# Epoch 110/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.7042 - val_loss: 0.6468
# Epoch 111/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.7168 - val_loss: 0.6789
# Epoch 112/200
# 5/5 [==============================] - 0s 102ms/step - loss: 0.7283 - val_loss: 0.5713
# Epoch 113/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.6855 - val_loss: 0.6624
# Epoch 114/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.7063 - val_loss: 0.5451
# Epoch 115/200
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6698 - val_loss: 0.5641
# Epoch 116/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.7386 - val_loss: 0.6220
# Epoch 117/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.7131 - val_loss: 0.6519
# Epoch 118/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.7268 - val_loss: 0.6705
# Epoch 119/200
# 5/5 [==============================] - 0s 105ms/step - loss: 0.6927 - val_loss: 0.6501
# Epoch 120/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.7155 - val_loss: 0.5820
# Epoch 121/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.7155 - val_loss: 0.5949
# Epoch 122/200
# 5/5 [==============================] - 0s 83ms/step - loss: 0.7023 - val_loss: 0.6128
# Epoch 123/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6296 - val_loss: 0.5768
# Epoch 124/200
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6757 - val_loss: 0.5516
# Epoch 125/200
# 5/5 [==============================] - 0s 82ms/step - loss: 0.7066 - val_loss: 0.6148
# Epoch 126/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6460 - val_loss: 0.5880
# Epoch 127/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6562 - val_loss: 0.6333
# Epoch 128/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.7157 - val_loss: 0.5614
# Epoch 129/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6642 - val_loss: 0.5785
# Epoch 130/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6773 - val_loss: 0.5524
# Epoch 131/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.6645 - val_loss: 0.5734
# Epoch 132/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6345 - val_loss: 0.6112
# Epoch 133/200
# 5/5 [==============================] - 0s 95ms/step - loss: 0.6364 - val_loss: 0.5242
# Epoch 134/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.6439 - val_loss: 0.5813
# Epoch 135/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6548 - val_loss: 0.6196
# Epoch 136/200
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6422 - val_loss: 0.6155
# Epoch 137/200
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6484 - val_loss: 0.6727
# Epoch 138/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.6593 - val_loss: 0.6745
# Epoch 139/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6637 - val_loss: 0.5946
# Epoch 140/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6592 - val_loss: 0.5710
# Epoch 141/200
# 5/5 [==============================] - 0s 101ms/step - loss: 0.6395 - val_loss: 0.5525
# Epoch 142/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6543 - val_loss: 0.5039
# Epoch 143/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6338 - val_loss: 0.5194
# Epoch 144/200
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6401 - val_loss: 0.5177
# Epoch 145/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.6126 - val_loss: 0.5926
# Epoch 146/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.6794 - val_loss: 0.6009
# Epoch 147/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.6358 - val_loss: 0.5580
# Epoch 148/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.6726 - val_loss: 0.5707
# Epoch 149/200
# 5/5 [==============================] - 0s 100ms/step - loss: 0.6482 - val_loss: 0.5851
# Epoch 150/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.6488 - val_loss: 0.6008
# Epoch 151/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.6622 - val_loss: 0.5551
# Epoch 152/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.6751 - val_loss: 0.5608
# Epoch 153/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.6228 - val_loss: 0.5923
# Epoch 154/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6472 - val_loss: 0.6488
# Epoch 155/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6591 - val_loss: 0.5997
# Epoch 156/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6451 - val_loss: 0.5985
# Epoch 157/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6238 - val_loss: 0.6217
# Epoch 158/200
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6250 - val_loss: 0.6233
# Epoch 159/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6136 - val_loss: 0.5734
# Epoch 160/200
# 5/5 [==============================] - 0s 90ms/step - loss: 0.6478 - val_loss: 0.5723
# Epoch 161/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.6673 - val_loss: 0.6530
# Epoch 162/200
# 5/5 [==============================] - 0s 103ms/step - loss: 0.6341 - val_loss: 0.6273
# Epoch 163/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6375 - val_loss: 0.6139
# Epoch 164/200
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6347 - val_loss: 0.6259
# Epoch 165/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.6414 - val_loss: 0.6596
# Epoch 166/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6301 - val_loss: 0.6675
# Epoch 167/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6463 - val_loss: 0.5804
# Epoch 168/200
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6666 - val_loss: 0.5646
# Epoch 169/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6521 - val_loss: 0.5778
# Epoch 170/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.6214 - val_loss: 0.5402
# Epoch 171/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.6336 - val_loss: 0.5430
# Epoch 172/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.6596 - val_loss: 0.6544
# Epoch 173/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6302 - val_loss: 0.5352
# Epoch 174/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6599 - val_loss: 0.5086
# Epoch 175/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6269 - val_loss: 0.5571
# Epoch 176/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.6368 - val_loss: 0.5571
# Epoch 177/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6233 - val_loss: 0.5414
# Epoch 178/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.6348 - val_loss: 0.5249
# Epoch 179/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.6499 - val_loss: 0.5831
# Epoch 180/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6246 - val_loss: 0.5965
# Epoch 181/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.6447 - val_loss: 0.5581
# Epoch 182/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.6357 - val_loss: 0.6586
# Epoch 183/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6334 - val_loss: 0.5946
# Epoch 184/200
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6223 - val_loss: 0.6087
# Epoch 185/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6429 - val_loss: 0.6045
# Epoch 186/200
# 5/5 [==============================] - 0s 80ms/step - loss: 0.5929 - val_loss: 0.6104
# Epoch 187/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.6106 - val_loss: 0.5673
# Epoch 188/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.6407 - val_loss: 0.5653
# Epoch 189/200
# 5/5 [==============================] - 0s 94ms/step - loss: 0.6313 - val_loss: 0.5662
# Epoch 190/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.6141 - val_loss: 0.5608
# Epoch 191/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.6548 - val_loss: 0.5677
# Epoch 192/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6225 - val_loss: 0.6074
# Epoch 193/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.5940 - val_loss: 0.5694
# Epoch 194/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.6015 - val_loss: 0.5443
# Epoch 195/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.6283 - val_loss: 0.5525
# Epoch 196/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6282 - val_loss: 0.5924
# Epoch 197/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6010 - val_loss: 0.5755
# Epoch 198/200
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6658 - val_loss: 0.5459
# Epoch 199/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.6237 - val_loss: 0.5578
# Epoch 200/200
# 5/5 [==============================] - 0s 103ms/step - loss: 0.6699 - val_loss: 0.5374
# <Axes: >

# %% [markdown]
# You'll typically get better performance if you standardize your data before using it for training. That we were able to use the raw data at all, however, shows how effective batch normalization can be on more difficult datasets.
