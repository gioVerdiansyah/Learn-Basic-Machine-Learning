# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/dropout-and-batch-normalization).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll add dropout to the *Spotify* model from Exercise 4 and see how batch normalization can let you successfully train models on difficult datasets.
#
# Run the next cell to get started!

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from tensorflow.keras import layers

spotify = pd.read_csv('./resources/datasets/spotify.csv')

X = spotify.copy().dropna()
y = X.pop('track_popularity')
artists = X['track_artist']

features_num = ['danceability', 'energy', 'key', 'loudness', 'mode',
                'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'duration_ms']
features_cat = ['playlist_genre']

preprocessor = make_column_transformer(
    (StandardScaler(), features_num),
    (OneHotEncoder(), features_cat),
)

def group_split(X, y, group, train_size=0.75):
    splitter = GroupShuffleSplit(train_size=train_size)
    train, test = next(splitter.split(X, y, groups=group))
    return (X.iloc[train], X.iloc[test], y.iloc[train], y.iloc[test])

X_train, X_valid, y_train, y_valid = group_split(X, y, artists)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
y_train = y_train / 100
y_valid = y_valid / 100

input_shape = [X_train.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Input shape: [18]

# %% [markdown]
# # 1) Add Dropout to Spotify Model
#
# Here is the last model from Exercise 4. Add two dropout layers, one after the `Dense` layer with 128 units, and one after the `Dense` layer with 64 units. Set the dropout rate on both to `0.3`.

# %%
# YOUR CODE HERE: Add two 30% dropout layers, one after 128 and one after 64
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(1)
])
# Out:
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# Now run this next cell to train the model see the effect of adding dropout.

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    verbose=0,
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()))
# Out:
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# Minimum Validation Loss: 0.1976

# %% [markdown]
# # 2) Evaluate Dropout
#
# Recall from Exercise 4 that this model tended to overfit the data around epoch 5. Did adding dropout seem to help prevent overfitting this time?
# <br>
# From the learning curves, you can see that the validation loss remains near a constant minimum even though the training loss continues to decrease. So we can see that adding dropout did prevent overfitting this time. Moreover, by making it harder for the network to fit spurious patterns, dropout may have encouraged the network to seek out more of the true patterns, possibly improving the validation loss some as well).

# %% [markdown]
# Now, we'll switch topics to explore how batch normalization can fix problems in training.
#
# Load the *Concrete* dataset. We won't do any standardization this time. This will make the effect of batch normalization much more apparent.

# %%
import pandas as pd

concrete = pd.read_csv('./resources/datasets/concrete.csv')
df = concrete.copy()

df_train = df.sample(frac=0.7, random_state=0)
df_valid = df.drop(df_train.index)

X_train = df_train.drop('CompressiveStrength', axis=1)
X_valid = df_valid.drop('CompressiveStrength', axis=1)
y_train = df_train['CompressiveStrength']
y_valid = df_valid['CompressiveStrength']

input_shape = [X_train.shape[1]]

# %% [markdown]
# Run the following cell to train the network on the unstandardized *Concrete* data.

# %%
model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=input_shape),
    layers.Dense(512, activation='relu'),    
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])
model.compile(
    optimizer='sgd', # SGD is more sensitive to differences of scale
    loss='mae',
    metrics=['mae'],
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=100
)

history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print(("Minimum Validation Loss: {:0.4f}").format(history_df['val_loss'].min()))
# Out:
# Epoch 1/100
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 12/12 [==============================] - 1s 40ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 2/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 3/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 4/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 5/100
# 12/12 [==============================] - 0s 17ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 6/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 7/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 8/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 9/100
# 12/12 [==============================] - 0s 14ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 10/100
# 12/12 [==============================] - 0s 25ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 11/100
# 12/12 [==============================] - 0s 20ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 12/100
# 12/12 [==============================] - 0s 17ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 13/100
# 12/12 [==============================] - 0s 17ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 14/100
# 12/12 [==============================] - 0s 18ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 15/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 16/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 17/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 18/100
# 12/12 [==============================] - 0s 19ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 19/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 20/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 21/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 22/100
# 12/12 [==============================] - 0s 12ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 23/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 24/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 25/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 26/100
# 12/12 [==============================] - 0s 14ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 27/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 28/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 29/100
# 12/12 [==============================] - 0s 12ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 30/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 31/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 32/100
# 12/12 [==============================] - 0s 13ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 33/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 34/100
# 12/12 [==============================] - 0s 13ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 35/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 36/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 37/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 38/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 39/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 40/100
# 12/12 [==============================] - 0s 17ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 41/100
# 12/12 [==============================] - 0s 21ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 42/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 43/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 44/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 45/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 46/100
# 12/12 [==============================] - 0s 13ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 47/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 48/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 49/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 50/100
# 12/12 [==============================] - 0s 14ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 51/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 52/100
# 12/12 [==============================] - 0s 13ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 53/100
# 12/12 [==============================] - 0s 14ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 54/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 55/100
# 12/12 [==============================] - 0s 13ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 56/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 57/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 58/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 59/100
# 12/12 [==============================] - 0s 14ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 60/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 61/100
# 12/12 [==============================] - 0s 14ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 62/100
# 12/12 [==============================] - 0s 20ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 63/100
# 12/12 [==============================] - 0s 17ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 64/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 65/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 66/100
# 12/12 [==============================] - 0s 13ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 67/100
# 12/12 [==============================] - 0s 13ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 68/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 69/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 70/100
# 12/12 [==============================] - 0s 13ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 71/100
# 12/12 [==============================] - 0s 14ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 72/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 73/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 74/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 75/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 76/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 77/100
# 12/12 [==============================] - 0s 13ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 78/100
# 12/12 [==============================] - 0s 13ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 79/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 80/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 81/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 82/100
# 12/12 [==============================] - 0s 17ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 83/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 84/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 85/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 86/100
# 12/12 [==============================] - 0s 14ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 87/100
# 12/12 [==============================] - 0s 13ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 88/100
# 12/12 [==============================] - 0s 16ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 89/100
# 12/12 [==============================] - 0s 17ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 90/100
# 12/12 [==============================] - 0s 22ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 91/100
# 12/12 [==============================] - 0s 17ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 92/100
# 12/12 [==============================] - 0s 18ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 93/100
# 12/12 [==============================] - 0s 23ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 94/100
# 12/12 [==============================] - 0s 20ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 95/100
# 12/12 [==============================] - 0s 19ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 96/100
# 12/12 [==============================] - 0s 17ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 97/100
# 12/12 [==============================] - 0s 17ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 98/100
# 12/12 [==============================] - 0s 18ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 99/100
# 12/12 [==============================] - 0s 14ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 100/100
# 12/12 [==============================] - 0s 15ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Minimum Validation Loss: nan

# %% [markdown]
# Did you end up with a blank graph? Trying to train this network on this dataset will usually fail. Even when it does converge (due to a lucky weight initialization), it tends to converge to a very large number.
#
# # 3) Add Batch Normalization Layers
#
# Batch normalization can help correct problems like this.
#
# Add four `BatchNormalization` layers, one before each of the dense layers. (Remember to move the `input_shape` argument to the new first layer.)

# %%
# YOUR CODE HERE: Add a BatchNormalization layer before each Dense layer
model = keras.Sequential([
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu', input_shape=input_shape),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(1),
])

# %% [markdown]
# Run the next cell to see if batch normalization will let us train the model.

# %%
model.compile(
    optimizer='sgd',
    loss='mae',
    metrics=['mae'],
)
EPOCHS = 100
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=68,
    epochs=EPOCHS,
    verbose=0,
)

history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print(("Minimum Validation Loss: {:0.4f}").format(history_df['val_loss'].min()))
# Out:
# Minimum Validation Loss: 3.7939

# %% [markdown]
# # 4) Evaluate Batch Normalization
#
# Did adding batch normalization help?
# <br>
# You can see that adding batch normalization was a big improvement on the first attempt! By adaptively scaling the data as it passes through the network, batch normalization can let you train models on difficult datasets.

# %% [markdown]
# # Keep Going #
#
# [**Create neural networks**](https://www.kaggle.com/ryanholbrook/binary-classification) for binary classification.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
