# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('./resources/datasets/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)
# Out:
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping]
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\Document\Learn Machine Learning\.venv\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 175/175 [==============================] - 7s 20ms/step - loss: 0.4800 - binary_accuracy: 0.7725 - val_loss: 0.4410 - val_binary_accuracy: 0.8041
# Epoch 2/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.4222 - binary_accuracy: 0.8015 - val_loss: 0.4064 - val_binary_accuracy: 0.8120
# Epoch 3/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.4093 - binary_accuracy: 0.8081 - val_loss: 0.4029 - val_binary_accuracy: 0.8149
# Epoch 4/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.4023 - binary_accuracy: 0.8124 - val_loss: 0.3934 - val_binary_accuracy: 0.8172
# Epoch 5/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3964 - binary_accuracy: 0.8147 - val_loss: 0.3898 - val_binary_accuracy: 0.8184
# Epoch 6/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3927 - binary_accuracy: 0.8175 - val_loss: 0.3857 - val_binary_accuracy: 0.8218
# Epoch 7/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3885 - binary_accuracy: 0.8188 - val_loss: 0.3825 - val_binary_accuracy: 0.8249
# Epoch 8/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3841 - binary_accuracy: 0.8223 - val_loss: 0.3818 - val_binary_accuracy: 0.8244
# Epoch 9/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3805 - binary_accuracy: 0.8234 - val_loss: 0.3775 - val_binary_accuracy: 0.8262
# Epoch 10/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3784 - binary_accuracy: 0.8248 - val_loss: 0.3775 - val_binary_accuracy: 0.8277
# Epoch 11/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3755 - binary_accuracy: 0.8256 - val_loss: 0.3729 - val_binary_accuracy: 0.8307
# Epoch 12/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3719 - binary_accuracy: 0.8270 - val_loss: 0.3727 - val_binary_accuracy: 0.8296
# Epoch 13/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3714 - binary_accuracy: 0.8287 - val_loss: 0.3722 - val_binary_accuracy: 0.8310
# Epoch 14/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3676 - binary_accuracy: 0.8298 - val_loss: 0.3689 - val_binary_accuracy: 0.8327
# Epoch 15/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3671 - binary_accuracy: 0.8298 - val_loss: 0.3724 - val_binary_accuracy: 0.8297
# Epoch 16/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3646 - binary_accuracy: 0.8316 - val_loss: 0.3694 - val_binary_accuracy: 0.8317
# Epoch 17/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3610 - binary_accuracy: 0.8329 - val_loss: 0.3650 - val_binary_accuracy: 0.8327
# Epoch 18/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3608 - binary_accuracy: 0.8320 - val_loss: 0.3649 - val_binary_accuracy: 0.8325
# Epoch 19/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3582 - binary_accuracy: 0.8346 - val_loss: 0.3648 - val_binary_accuracy: 0.8333
# Epoch 20/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3584 - binary_accuracy: 0.8339 - val_loss: 0.3613 - val_binary_accuracy: 0.8340
# Epoch 21/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3563 - binary_accuracy: 0.8357 - val_loss: 0.3655 - val_binary_accuracy: 0.8313
# Epoch 22/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3555 - binary_accuracy: 0.8351 - val_loss: 0.3602 - val_binary_accuracy: 0.8352
# Epoch 23/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3538 - binary_accuracy: 0.8370 - val_loss: 0.3608 - val_binary_accuracy: 0.8347
# Epoch 24/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3527 - binary_accuracy: 0.8378 - val_loss: 0.3579 - val_binary_accuracy: 0.8374
# Epoch 25/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3509 - binary_accuracy: 0.8380 - val_loss: 0.3597 - val_binary_accuracy: 0.8377
# Epoch 26/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3500 - binary_accuracy: 0.8387 - val_loss: 0.3590 - val_binary_accuracy: 0.8361
# Epoch 27/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3486 - binary_accuracy: 0.8390 - val_loss: 0.3572 - val_binary_accuracy: 0.8373
# Epoch 28/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3477 - binary_accuracy: 0.8401 - val_loss: 0.3566 - val_binary_accuracy: 0.8364
# Epoch 29/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3478 - binary_accuracy: 0.8393 - val_loss: 0.3564 - val_binary_accuracy: 0.8388
# Epoch 30/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3459 - binary_accuracy: 0.8405 - val_loss: 0.3580 - val_binary_accuracy: 0.8382
# Epoch 31/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3452 - binary_accuracy: 0.8402 - val_loss: 0.3562 - val_binary_accuracy: 0.8379
# Epoch 32/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3449 - binary_accuracy: 0.8412 - val_loss: 0.3563 - val_binary_accuracy: 0.8377
# Epoch 33/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3425 - binary_accuracy: 0.8428 - val_loss: 0.3534 - val_binary_accuracy: 0.8396
# Epoch 34/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3409 - binary_accuracy: 0.8427 - val_loss: 0.3549 - val_binary_accuracy: 0.8386
# Epoch 35/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3415 - binary_accuracy: 0.8418 - val_loss: 0.3537 - val_binary_accuracy: 0.8400
# Epoch 36/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3411 - binary_accuracy: 0.8429 - val_loss: 0.3529 - val_binary_accuracy: 0.8408
# Epoch 37/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3419 - binary_accuracy: 0.8418 - val_loss: 0.3542 - val_binary_accuracy: 0.8385
# Epoch 38/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3375 - binary_accuracy: 0.8439 - val_loss: 0.3533 - val_binary_accuracy: 0.8397
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?
# <br>
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
